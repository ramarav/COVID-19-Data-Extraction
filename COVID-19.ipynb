# %%
import pandas as pd

# %%
df = pd.read_csv('https://opendata.ecdc.europa.eu/covid19/casedistribution/csv')

# %%
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      09/06/2020    9      6  2020    575      12             Afghanistan
# 1      08/06/2020    8      6  2020    791      30             Afghanistan
# 2      07/06/2020    7      6  2020    582      18             Afghanistan
# 3      06/06/2020    6      6  2020    915       9             Afghanistan
# 4      05/06/2020    5      6  2020    787       6             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 22378  25/03/2020   25      3  2020      0       0                Zimbabwe
# 22379  24/03/2020   24      3  2020      0       1                Zimbabwe
# 22380  23/03/2020   23      3  2020      0       0                Zimbabwe
# 22381  22/03/2020   22      3  2020      1       0                Zimbabwe
# 22382  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018 continentExp
# ...

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  09/06/2020    9      6  2020    575      12             Afghanistan    AF
# 1  08/06/2020    8      6  2020    791      30             Afghanistan    AF
# 2  07/06/2020    7      6  2020    582      18             Afghanistan    AF
# 3  06/06/2020    6      6  2020    915       9             Afghanistan    AF
# 4  05/06/2020    5      6  2020    787       6             Afghanistan    AF
#
#   countryterritoryCode  popData2018 continentExp
# 0                  AFG   37172386.0         Asia
# 1                  AFG   37172386.0         Asia
# 2                  AFG   37172386.0         Asia
# 3                  AFG   37172386.0         Asia
# 4                  AFG   37172386.0         Asia
